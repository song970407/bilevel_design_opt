# %%
import sys
sys.path.append('..')

# %%
# %matplotlib inline

import os
import pickle

import numpy as np
import matplotlib.pyplot as plt
import torch
import dgl

from src.model.get_model import get_model
from src.utils.preprocess_data import preprocess_data
from src.utils.fix_seed import fix_seed
fix_seed()
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# Using backend: pytorch

# %%
def model_prediction_test(model, test_data, test_config):
    test_states = test_data['state_list']
    test_actions = test_data['action_list']
    test_graphs = test_data['graph_list']

    receding_history = test_config['receding_history']
    receding_horizon = test_config['receding_horizon']
    state_scaler = test_config['state_scaler']
    action_scaler = test_config['action_scaler']

    with torch.no_grad():
        test_history_xs_list, test_history_us_list, test_us_list, test_ys_list, test_graph_list, test_idxs = preprocess_data(states=test_states,
                                                                                                                             actions=test_actions,
                                                                                                                             graphs=test_graphs,
                                                                                                                             receding_history=receding_history,
                                                                                                                             receding_horizon=receding_horizon,
                                                                                                                             state_scaler=state_scaler,
                                                                                                                             action_scaler=action_scaler,
                                                                                                                             device=DEVICE)
        test_batch_size = test_idxs.shape[0]
        test_gs = dgl.batch([test_graph_list[test_idxs[idx, 0]] for idx in range(test_batch_size)])
        test_history_x = torch.cat([test_history_xs_list[test_idxs[idx, 0]][test_idxs[idx, 1]] for idx in range(test_batch_size)])
        test_history_u = torch.cat([test_history_us_list[test_idxs[idx, 0]][test_idxs[idx, 1]] for idx in range(test_batch_size)])
        test_u = torch.cat([test_us_list[test_idxs[idx, 0]][test_idxs[idx, 1]] for idx in range(test_batch_size)])
        test_y = torch.cat([test_ys_list[test_idxs[idx, 0]][test_idxs[idx, 1]] for idx in range(test_batch_size)])
        hs = model.filter_history(test_gs, test_history_x, test_history_u)
        predicted_y = model.multi_step_prediction(test_gs, hs, test_u)
    return test_y, predicted_y

# %%
with open('data/env_config.pkl', 'rb') as f:
    env_config = pickle.load(f)
num_cells = env_config['num_cells']
dt = env_config['dt']
epsilon = env_config['epsilon']
domain_range = env_config['domain_range']
action_min = env_config['action_min']
action_max = env_config['action_max']
state_scaler = env_config['state_scaler']
action_scaler = env_config['action_scaler']
x_dim = 1
u_dim = 1
receding_history = 5
receding_horizon = 10

test_config = {
    'receding_history': receding_history,
    'receding_horizon': receding_horizon,
    'state_scaler': state_scaler,
    'action_scaler': action_scaler
}

# Prepare to load models
model_names = ['GAT', 'ICGAT']
data_ratio_list = [0.05, 0.1]
hidden_dim = 64
is_convex = False

# Prepare test data
test_data_path_list = ['data/ground_truth/test_data.pkl', 'data/ground_truth/out_distribution_data.pkl']
fig_title_list = ['ID', 'OOD']
for (idx, test_data_path) in enumerate(test_data_path_list):
    with open(test_data_path, 'rb') as f:
        test_data = pickle.load(f)
    criteria = torch.nn.SmoothL1Loss(reduction='none')
    for data_ratio in data_ratio_list:
        fig, axes = plt.subplots(1, 1)
        true_ys = []
        predicted_ys = []
        for model_name in model_names:
            saved_model_path = 'saved_model/{}_{}.pt'.format(model_name, data_ratio)
            model = get_model(model_name, hidden_dim, is_convex, saved_model_path).to(DEVICE)
            true_y, predicted_y = model_prediction_test(model, test_data, test_config)
            true_ys.append(true_y)
            predicted_ys.append(predicted_y)
            dif = criteria(true_y, predicted_y)[:, :, 0]
            dif_mean = torch.mean(dif, dim=0).cpu().detach().numpy()
            dif_mean = np.concatenate([np.zeros(1), dif_mean])
            dif_std = torch.std(dif, dim=0).cpu().detach().numpy()
            dif_std = np.concatenate([np.zeros(1), dif_std])
            axes.plot(dif_mean, label='{}_{}'.format(model_name, data_ratio), linewidth=4)
            axes.fill_between(np.arange(len(dif_mean)), dif_mean - 0.1 * dif_std, dif_mean + 0.1 * dif_std, alpha=0.2)
            print('{}_{}, Loss Min: {}, Mean: {}, Max: {}'.format(model_name, data_ratio, torch.min(dif[:, 0]), torch.mean(dif[:, 0]), torch.max(dif[:, 0])))
        axes.legend(fontsize=15)
        axes.set_xlabel('Rollout Steps', size=15)
        axes.set_ylabel('MSE', size=15)
        fig.suptitle(fig_title_list[idx], size=20)
        fig.show()
# Out:
# GAT_0.05, Loss Min: 8.992806499463768e-13, Mean: 0.0003862514568027109, Max: 0.005244601983577013
# ICGAT_0.05, Loss Min: 1.1102230246251565e-14, Mean: 0.000884890672750771, Max: 0.02151329442858696
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\ipykernel_launcher.py:58: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
# GAT_0.1, Loss Min: 1.0231815394945443e-12, Mean: 0.0001523782266303897, Max: 0.0020614811219274998
# ICGAT_0.1, Loss Min: 2.5579538487363607e-13, Mean: 0.000979000935330987, Max: 0.02065655216574669
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\ipykernel_launcher.py:58: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\SONGCH~1\AppData\Local\Temp/ipykernel_35416/1351401952.py in <module>
#      41             saved_model_path = 'saved_model/{}_{}.pt'.format(model_name, data_ratio)
#      42             model = get_model(model_name, hidden_dim, is_convex, saved_model_path).to(DEVICE)
# ---> 43             true_y, predicted_y = model_prediction_test(model, test_data, test_config)
#      44             true_ys.append(true_y)
#      45             predicted_ys.append(predicted_y)
#
# C:\Users\SONGCH~1\AppData\Local\Temp/ipykernel_35416/2606326050.py in model_prediction_test(model, test_data, test_config)
#      25         test_y = torch.cat([test_ys_list[test_idxs[idx, 0]][test_idxs[idx, 1]] for idx in range(test_batch_size)])
#      26         hs = model.filter_history(test_gs, test_history_x, test_history_u)
# ---> 27         predicted_y = model.multi_step_prediction(test_gs, hs, test_u)
#      28     return test_y, predicted_y
#
# ~\project\ICGNN-Private\experiment_src\HeatSimulator\SIAM\src\model\GRNN.py in multi_step_prediction(self, g, h, us)
#      53         :return:
#      54         """
# ---> 55         return self.rollout(g, h, us)
#
# ~\project\ICGNN-Private\experiment_src\HeatSimulator\SIAM\src\model\GRNN.py in rollout(self, g, h, us)
#      40         hs = []
#      41         for u in us:
# ---> 42             h = self.encode(g, h, u)
#      43             hs.append(h)
#      44         hs = torch.stack(hs, dim=-2)
#
# ~\project\ICGNN-Private\experiment_src\HeatSimulator\SIAM\src\model\GRNN.py in encode(self, g, h, u)
#      15
#      16     def encode(self, g, h, u):
# ---> 17         return self.encoder(g, h, u)
#      18
#      19     def decode(self, x):
#
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\project\ICGNN-Private\experiment_src\HeatSimulator\SIAM\src\model\Encoders.py in forward(self, g, h, u)
#     223             g.nodes['action'].data['u'] = u
#     224             g.update_all(self.u2h_msg, fn.sum('u2h_msg', 'sum_u'), etype='a2s')
# --> 225             g[s2s].apply_edges(self.h2h_msg)
#     226             g[s2s].edata['h2h_attn'] = edge_softmax(g[s2s], g[s2s].edata['h2h_logit'])
#     227             g.update_all(self.message_func, fn.sum('m', 'sum_h'), etype='s2s')
#
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\dgl\heterograph.py in apply_edges(self, func, edges, etype, inplace)
#    4423             edata = core.invoke_gsddmm(g, func)
#    4424         else:
# -> 4425             edata = core.invoke_edge_udf(g, eid, etype, func)
#    4426         self._set_e_repr(etid, eid, edata)
#    4427
#
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\dgl\core.py in invoke_edge_udf(graph, eid, etype, func, orig_eid)
#      83     ebatch = EdgeBatch(graph, eid if orig_eid is None else orig_eid,
#      84                        etype, srcdata, edata, dstdata)
# ---> 85     return func(ebatch)
#      86
#      87 def invoke_udf_reduce(graph, func, msgdata, *, orig_nid=None):
#
# ~\project\ICGNN-Private\experiment_src\HeatSimulator\SIAM\src\model\Encoders.py in h2h_msg(self, edges)
#     246         src_h = edges.src['h']
#     247         inp = torch.cat([src_pos, dst_pos, edge_dis], dim=-1)
# --> 248         return {'h2h_logit': self.h2h_enc_dis(inp), 'h2h_msg': self.h2h_enc_h(src_h)}
#     249
#     250     @staticmethod
#
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# c:\users\song chi hyeon\anaconda3\envs\mpc37\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:
